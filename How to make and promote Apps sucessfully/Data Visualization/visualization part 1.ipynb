# %%
import pandas as pd
import numpy as np
df = pd.read_csv("google app final.csv")
df
# Out:
#       Unnamed: 0                                              title  score  \
# 0              0                                        Brawl Stars    4.6
# 1              1                                       Popular Wars    4.0
# 2              2                                     Drive and Park    4.2
# 3              3                                      Fire Balls 3D    4.5
# 4              4                                             TikTok    4.4
# 5              5           Messenger – Text and Video Chat for Free    4.1
# 6              6                                      Stickman Hook    4.1
# 7              7                         Lucky Day - Win Real Money    4.6
# 8              8                                         Paper.io 2    4.4
# 9              9                                    Amazon Shopping    4.3
# 10            10                                           Snapchat    4.1
# 11            11                                 WhatsApp Messenger    4.4
# 12            12                                          Instagram    4.5
# 13            13                                            Netflix    4.4
# 14            14                                         Helix Jump    4.3
# 15            15                  Words Story - Addictive Word Game    4.5
# 16            16                                           Facebook    4.1
# 17            17                                      Spotify Music    4.6
# 18            18        YouTube Music - Stream Songs & Music Videos    4.2
# 19            19                                   BURGER KING® App    4.0
# 20            20                                            Walmart    4.4
# 21            21                           Wish - Shopping Made Fun    4.5
# 22            22                                      Pandora Music    4.4
# 23            23                          Escape Room: Mystery Word    4.5
# 24            24                                  Google Play Games    4.3
# 25            25         Looney Tunes™ World of Mayhem - Action RPG    4.4
# 26            26                                 Amazon Prime Video    4.3
# 27            27                                         Swing Star    4.1
# 28            28               Find The Differences - The Detective    4.6
# 29            29                               Tiles Hop: EDM Rush!    4.5
# ...          ...                                                ...    ...
# 1050         510                     Siralim 3 (Monster Taming RPG)    4.9
# 1051         511                   One + Gestures — Gesture Control    4.5
# 1052         512                     BeerSmith 3 Mobile Homebrewing    4.2
# 1053         513                Transparent clock weather (Ad-free)    4.6
# 1054         514                                       Magic Fluids    4.7
# 1055         515                                   Through the Ages    4.9
# 1056         516                                   Bloom: 10 Worlds    4.6
# 1057         517                                           Osmos HD    4.7
# 1058         518                                 Toca Mystery House    4.2
# 1059         519                                Ben 10: Up to Speed    4.2
# 1060         520                       Equalizer & Bass Booster Pro    4.5
# 1061         521                        Pip-Boy Watchface  [+Bonus]    3.8
# 1062         522                     Ravensword: Shadowlands 3d RPG    4.0
# 1063         523                           PixBit - Pixel Icon Pack    4.8
# 1064         524                                    MediaMonkey Pro    4.2
# 1065         525                           Meme Soundboard PRO 2018    4.7
# 1066         526                         inCarDoc Pro | ELM327 OBD2    4.2
# 1067         527                                      Root Explorer    4.7
# 1068         528                          Knights of Pen & Paper +1    4.5
# 1069         529  PUB Gfx+ Tool🔧:#1 GFX Tool(with advance settings)    4.5
# 1070         530                      TuneIn Radio Pro - Live Radio    4.2
# 1071         531                                Anti Spy Mobile PRO    4.3
# 1072         532                                         iBend Pipe    3.4
# 1073         533                                       Tactical NAV    5.0
# 1074         534                                    Toca Life: City    4.7
# 1075         535                                           holedown    4.5
# 1076         536                         Papa's Hot Doggeria To Go!    4.6
# 1077         537                                    The Banner Saga    4.4
# 1078         538                                 Land Nav Assistant    4.3
# 1079         539                                 Bridge Constructor    4.4
#
#                     size        installs content_rating           category  \
# 0                    85M     10,000,000+   Everyone 10+             Action
# 1                    53M      5,000,000+       Everyone             Action
# 2                    39M      1,000,000+           Teen         Simulation
# 3                    47M     10,000,000+           Teen             Arcade
# 4                    69M    100,000,000+           Teen             Social
# 5     Varies with device  1,000,000,000+       Everyone      Communication
# 6                    52M     10,000,000+       Everyone             Arcade
# 7                    92M      5,000,000+           Teen             Casino
# 8                    48M     10,000,000+       Everyone             Arcade
# 9                    49M    100,000,000+           Teen           Shopping
# 1051  Paid   December 8, 2018
# 1052  Paid    October 9, 2018
# 1053  Paid  December 13, 2018
# 1054  Paid     August 5, 2016
# 1055  Paid   December 3, 2018
# 1056  Paid   December 6, 2018
# 1057  Paid        May 7, 2015
# 1058  Paid      June 14, 2018
# 1059  Paid    August 16, 2018
# 1060  Paid  September 6, 2018
# 1061  Paid        May 1, 2018
# 1062  Paid   November 8, 2013
# 1063  Paid   December 8, 2018
# 1064  Paid     March 10, 2015
# 1065  Paid     August 5, 2018
# 1066  Paid   December 7, 2018
# 1067  Paid   October 29, 2018
# 1068  Paid      July 11, 2018
# 1069  Paid  December 13, 2018
# 1070  Paid   December 6, 2018
# 1071  Paid  November 14, 2018
# 1072  Paid   December 8, 2017
# 1073  Paid  November 29, 2018
# 1074  Paid       July 6, 2018
# 1075  Paid  November 16, 2018
# 1076  Paid     August 3, 2018
# 1077  Paid   February 7, 2017
# 1078  Paid    August 13, 2018
# 1079  Paid  September 5, 2018
#
# [1080 rows x 9 columns]

# %%
from wordcloud import WordCloud
df_category = df["category"]
text = df_category
result= "/".join(text) #要分割开才行 如果是txt还要用jieba
wordcloud = WordCloud(font_path="c:\windows\Fonts\simhei.ttf").generate(result) 
# %pylab inline
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\software\AnacondaNavigator\install\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['text']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# (-0.5, 399.5, 199.5, -0.5)

# %%
df['installs'] = df['installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)
df['installs'] = df['installs'].apply(lambda x: x.replace(',', '') if ',' in str(x) else x)
df['installs'] = df['installs'].apply(lambda x: int(x))
df['installs']=df['installs'].astype('float')

# %%
#installs = []
#category = []
#for i in df["installs"]:
   # installs = installs.append(i)
#print(installs)

# %%
# 可以看到 最多的是Family 其次 Game Medical Tools 等等 但是看下面的图发现，提供最多的的分类并不是下载最多的
# 在这里Google store的提供和用户的需要就有堕距了

# %%
import pandas as pd
import matplotlib.pyplot as plt  
plt.rcParams['font.sans-serif'] = [u'SimHei']
plt.rcParams['axes.unicode_minus'] = False

df = pd.DataFrame({'Category':df["category"],'Installs':df["installs"]})
groupbyDistrict=df.groupby('Category')
groupbyD = groupbyDistrict.mean().sort_values('Installs', ascending=False).reset_index()

'''
groupbyD.columns = groupbyD.columns.droplevel(0) 
groupbyClass.rename(columns = {'':'Installs'},inplace = True)
'''
ax = groupbyD.head(3).plot.bar(x='Category', y='Installs', rot=0, color = ["g","y","y","y","y"])

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("googleapp Data cleaning.csv")

import pandas as pd
import matplotlib.pyplot as plt  
plt.rcParams['font.sans-serif'] = [u'SimHei']
plt.rcParams['axes.unicode_minus'] = False

df = pd.DataFrame({'Reviews':df["Reviews"],'Installs':df["Installs"]})
groupbyDistrict=df.groupby('Reviews')
groupbyD = groupbyDistrict.mean().sort_values('Installs', ascending=True).reset_index()
plt.plot(groupbyD.head(100))
plt.show()

# %%
#df['Reviews']

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("googleapp Data cleaning.csv")
df


import pandas as pd
import matplotlib.pyplot as plt  
plt.rcParams['font.sans-serif'] = [u'SimHei']
plt.rcParams['axes.unicode_minus'] = False

df = pd.DataFrame({'Reviews':df["Reviews"],'Installs':df["Installs"]})

groupbyDistrict=df.groupby('Reviews')


groupbyD = groupbyDistrict.mean().sort_values('Installs', ascending=True).reset_index()
#print(groupbyD)

#ax = df.plot.bar(x='Reviews', y='Installs', rot=270)

print(groupbyD.head())
plt.plot(groupbyD.head(100))
plt.show()
# Out:
#    Reviews    Installs
# 0        1   48.222222
# 1       49  100.000000
# 2        2  170.642857
# 3        3  175.365854
# 4       13  200.000000
