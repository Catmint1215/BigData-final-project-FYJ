# %%
# Facebook 的评论

# %%
import pandas as pd
import numpy as np
df_facebook = pd.read_csv('facebook.csv')
df_facebook.mean()
# Out:
# Subjectivity    0.473283
# Polarity       -0.014945
# dtype: float64

# %%
from pyecharts import Pie
from IPython.display import IFrame
attr = ['Negative','Neutral','Positive']
v1 = [18,4,18]
pie = Pie(width ='100%', height='100vh')
pie.add('',attr,v1,is_label_show = True)
pie.render('facebook_Polarity.html') 
pie
# Out:
# ERROR:lml.utils:failed to import pyecharts_snapshot
# Traceback (most recent call last):
#   File "C:\software\AnacondaNavigator\install\lib\site-packages\lml\utils.py", line 43, in do_import
#     plugin_module = __import__(plugin_module_name)
# ModuleNotFoundError: No module named 'pyecharts_snapshot'
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="10a8ac25fb274e8f8f14ee05b0984f29" style="width:100%;height:100vh;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_10a8ac25fb274e8f8f14ee05b0984f29 = echarts.init(document.getElementById('10a8ac25fb274e8f8f14ee05b0984f29'), 'light', {renderer: 'canvas'});
#
# var option_10a8ac25fb274e8f8f14ee05b0984f29 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5096279,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "Negative",
#                     "value": 18
#                 },
#                 {
#                     "name": "Neutral",
#                     "value": 4
#                 },
#                 {
#                     "name": "Positive",
#                     "value": 18
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 5096279
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Negative",
#                 "Neutral",
#                 "Positive"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_10a8ac25fb274e8f8f14ee05b0984f29.setOption(option_10a8ac25fb274e8f8f14ee05b0984f29);
#
#     });
# </script>

# %%
attr = ['Subjective','Objective']
v1 = [19,21]
pie = Pie(width ='100%', height='100vh')
pie.add('',attr,v1,is_label_show = True)
pie.render('Facebook_Subjectivity.html') 
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="dd6e6f1a36364217b515436ce4ff295c" style="width:100%;height:100vh;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_dd6e6f1a36364217b515436ce4ff295c = echarts.init(document.getElementById('dd6e6f1a36364217b515436ce4ff295c'), 'light', {renderer: 'canvas'});
#
# var option_dd6e6f1a36364217b515436ce4ff295c = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3963096,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "Subjective",
#                     "value": 19
#                 },
#                 {
#                     "name": "Objective",
#                     "value": 21
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 3963096
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Subjective",
#                 "Objective"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_dd6e6f1a36364217b515436ce4ff295c.setOption(option_dd6e6f1a36364217b515436ce4ff295c);
#
#     });
# </script>

# %%
# Pass 的评论

# %%
import pandas as pd
import numpy as np
df_pass = pd.read_csv('pass.csv')
df_pass.mean()
# Out:
# Subjectivity    0.219292
# Polarity       -0.097603
# dtype: float64

# %%
from pyecharts import Pie
from IPython.display import IFrame

attr = ['Negative','Neutral','Positive']
v1 = [14,12,4]
pie = Pie(width='100%', height='100vh')
pie.add('',attr,v1,is_label_show = True)


pie.render('Pass_Polarity.html') 

pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="8999d65b9e7245548209e50d350ce283" style="width:100%;height:100vh;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_8999d65b9e7245548209e50d350ce283 = echarts.init(document.getElementById('8999d65b9e7245548209e50d350ce283'), 'light', {renderer: 'canvas'});
#
# var option_8999d65b9e7245548209e50d350ce283 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4923432,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "Negative",
#                     "value": 14
#                 },
#                 {
#                     "name": "Neutral",
#                     "value": 12
#                 },
#                 {
#                     "name": "Positive",
#                     "value": 4
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 4923432
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Negative",
#                 "Neutral",
#                 "Positive"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_8999d65b9e7245548209e50d350ce283.setOption(option_8999d65b9e7245548209e50d350ce283);
#
#     });
# </script>

# %%
attr = ['Subjective','Objective']
v1 = [9,31]
pie = Pie(width ='100%', height='100vh')
pie.add('',attr,v1,is_label_show = True)
pie.render('Pass_Subjectivity.html') 
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e1f2fa1725e8468e8c0357722fb400e0" style="width:100%;height:100vh;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e1f2fa1725e8468e8c0357722fb400e0 = echarts.init(document.getElementById('e1f2fa1725e8468e8c0357722fb400e0'), 'light', {renderer: 'canvas'});
#
# var option_e1f2fa1725e8468e8c0357722fb400e0 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8599175,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "Subjective",
#                     "value": 9
#                 },
#                 {
#                     "name": "Objective",
#                     "value": 31
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 8599175
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Subjective",
#                 "Objective"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_e1f2fa1725e8468e8c0357722fb400e0.setOption(option_e1f2fa1725e8468e8c0357722fb400e0);
#
#     });
# </script>
